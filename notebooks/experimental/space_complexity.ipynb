# %% [markdown]
# # Space complexity of BertNer and FlairNer models

# %%
# models
import sys
from danlp.models import load_bert_ner_model, load_flair_ner_model

# %%
# load models
bert = load_bert_ner_model()
flair = load_flair_ner_model()
# Out:
# 2021-01-12 11:58:33,141 loading file /Users/jorgentaule/.danlp/flair.ner.pt

# %%
sys.getsizeof(bert), sys.getsizeof(flair)
# Out:
# (56, 56)

# %%
bert.model.classifier
# Out:
# Linear(in_features=768, out_features=9, bias=True)

# %%
flair.linear
# Out:
# Linear(in_features=512, out_features=10, bias=True)

# %%
bert.model
# Out:
# BertForTokenClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(32000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
dir(flair)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_calculate_loss',
#  '_call_impl',
#  '_fetch_model',
#  '_filter_empty_sentences',
#  '_filter_empty_string',
#  '_forward_alg',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_forward_unimplemented',
#  '_get_name',
#  '_get_state_dict',
#  '_init_model_with_state_dict',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_obtain_labels',
# ...

# %%
flair
# Out:
# SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): WordEmbeddings('da')
#     (list_embedding_1): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.5, inplace=False)
#         (encoder): Embedding(275, 100)
#         (rnn): LSTM(100, 1032)
#         (decoder): Linear(in_features=1032, out_features=275, bias=True)
#       )
#     )
#     (list_embedding_2): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.5, inplace=False)
#         (encoder): Embedding(275, 100)
#         (rnn): LSTM(100, 1032)
#         (decoder): Linear(in_features=1032, out_features=275, bias=True)
#       )
#     )
#   )
#   (word_dropout): WordDropout(p=0.05)
#   (locked_dropout): LockedDropout(p=0.5)
#   (embedding2nn): Linear(in_features=2364, out_features=2364, bias=True)
#   (rnn): LSTM(2364, 256, batch_first=True, bidirectional=True)
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
dir(flair.tag_dictionary)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_item',
#  'get_idx_for_item',
#  'get_idx_for_items',
#  'get_item_for_index',
#  'get_items',
#  'idx2item',
#  'item2idx',
#  'load',
#  'load_from_file',
#  'multi_label',
#  'save']

# %%
flair.tag_dictionary.get_items()
# Out:
# ['<unk>',
#  'O',
#  'B-ORG',
#  'B-PER',
#  'I-PER',
#  'B-LOC',
#  'I-ORG',
#  'I-LOC',
#  '<START>',
#  '<STOP>']
